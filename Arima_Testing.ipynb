# %% [markdown]
# <a href="https://colab.research.google.com/github/Nonso-M/Parkinson-data-prediction/blob/main/Arima_Testing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
arr= [[1, 3,5,6,np.nan, np.nan, 6], 
       [4,5,np.nan, 6,87, 33, np.nan],
        [np.nan,3,4,5,6,7,8],
        [8,6,5,3, np.nan,np.nan, np.nan]]
df = pd.DataFrame(arr)

# %%
import pandas as pd
import numpy as np

# %%
df= pd.read_excel("Borno.xlsx")

# %%
import requests

# %%
from requests.auth import HTTPDigestAuth

user = 'dr.muntaqa'
password = 'Access.190e'

res = requests.get('http://data.nphcdaict.com.ng/ODKAggregate/view/binaryData?blobKey=TEST_QST_PHC_BHCPF_ENUGU%26frasl%3BCROSS-RIVERS%5B%40version%3Dnull+and+%40uiVersion%3Dnull%5D%2FBHCPF_MOBILE%5B%40key%3Duuid%3A81134e90-c2ae-4654-9fd4-27a736dbe58c%5D%2Fsurv_start%3AGenInfo001%3Apicgen23', auth=(user, password))

# %%
res.status_code
# Out:
# 403

# %%
df1=pd.DataFrame({"Column1": ['Happiness', 'Continuation', 'Jovialization',None],
                         "Column2": [None, None, "happiness", 'Betterlife'],
                         "Column3": ['Happiness','Continuation',  'Betterlife',None],
                         "Column4": [None, None,None , 'Happiness']})

# %%
listsss= load_links(df1)

# %%
def remove_unicode(string):
   if type(string)== list:
     string= " ".join(string)
   strencode = string.encode("ascii", "ignore")
    # decode() method
   text = strencode.decode()

   return text
  # clean_list = []
  # for word in my_list:
  #   encode_word = word.encode("ascii", "ignore")
  #   clean_word = encode_word.decode()
  #   clean_list.append(clean_word)

  #   return clean_list

# %%
y= remove_unicode('obstruction. ·\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0Laser Lithotripsy ')
print(y)
# Out:
# obstruction. Laser Lithotripsy

# %%
state_links_df = pd.read_excel("Borno.xlsx")

# %%
    for column in list(state_links_df.columns):

        # loop through  the links in a df column
        counter = 1
        for link in state_links_df[column][0:5]:
          print(link)
# Out:
# http://data.nphcdaict.com.ng/ODKAggregate/view/binaryData?blobKey=QST_PHC_BHCPF_BORNO_Prod%5B%40version%3Dnull+and+%40uiVersion%3Dnull%5D%2FBHCPF_MOBILE%5B%40key%3Duuid%3A7f52c976-2e26-40f9-b2b4-ac6ffb612fbd%5D%2Fsurv_start%3AGenInfo001%3Apicgen23
# http://data.nphcdaict.com.ng/ODKAggregate/view/binaryData?blobKey=QST_PHC_BHCPF_BORNO_Prod%5B%40version%3Dnull+and+%40uiVersion%3Dnull%5D%2FBHCPF_MOBILE%5B%40key%3Duuid%3A5feb9701-008a-4219-a307-6e886f2fb131%5D%2Fsurv_start%3AGenInfo001%3Apicgen23
# http://data.nphcdaict.com.ng/ODKAggregate/view/binaryData?blobKey=QST_PHC_BHCPF_BORNO_Prod%5B%40version%3Dnull+and+%40uiVersion%3Dnull%5D%2FBHCPF_MOBILE%5B%40key%3Duuid%3A9e080da8-fa4a-4699-a601-15741d427607%5D%2Fsurv_start%3AGenInfo001%3Apicgen23
# http://data.nphcdaict.com.ng/ODKAggregate/view/binaryData?blobKey=QST_PHC_BHCPF_BORNO_Prod%5B%40version%3Dnull+and+%40uiVersion%3Dnull%5D%2FBHCPF_MOBILE%5B%40key%3Duuid%3Aef07ce67-9f04-491e-8920-640f97eba384%5D%2Fsurv_start%3AGenInfo001%3Apicgen23
# ...

# %%
print(filter_nonenglish('non-english news répondre non-english news à un ensemble de contraintes, non-english news notamment, l’extrême '))
# Out:
# 3

# %%
import json

new_list= [json.loads(lines) for lines in open('USA Government.txt')]

# %%
new_list
time_zone= [love['tz'] for love in new_list if 'tz' in love]
time_zone

# %%
from collections import defaultdict
def counterr(x: list):
  new_dict= defaultdict(int)
  for instance in x:
    new_dict[instance]+= 1

  return new_dict

# %%
countr = counterr(time_zone)
countr

newting =dict(countr)

# %%
sort_counter= dict(sorted(countr.items(), key= lambda x: x[1]))
sort_counter

# %%
len(sort_counter)
len(time_zone)
# Out:
# 3440

# %%
dict(y)
# Out:
# {0: 0, 1: 2, 2: 1, 3: 4, 4: 3}

# %%
def truncate_dict(zone: dict, n: int):
  list_a= [(a, b) for a, b in zone.items()]
  list_a.sort(key= lambda x: x[1], reverse= True)
  return list_a[:n]

# %%
bb= truncate_dict(countr, 10)
bb
# Out:
# [('America/New_York', 1251),
#  ('', 521),
#  ('America/Chicago', 400),
#  ('America/Los_Angeles', 382),
#  ('America/Denver', 191),
#  ('Europe/London', 74),
#  ('Asia/Tokyo', 37),
#  ('Pacific/Honolulu', 36),
#  ('Europe/Madrid', 35),
#  ('America/Sao_Paulo', 33)]

# %%
import pandas as pd

df= pd.DataFrame(new_list)
df
# Out:
#                                                       a   c   nk  \
# 0     Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKi...  US  1.0
# 1                                GoogleMaps/RochesterNY  US  0.0
# 2     Mozilla/4.0 (compatible; MSIE 8.0; Windows NT ...  US  1.0
# 3     Mozilla/5.0 (Macintosh; Intel Mac OS X 10_6_8)...  BR  0.0
# 4     Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKi...  US  0.0
# ...                                                 ...  ..  ...
# 3555  Mozilla/4.0 (compatible; MSIE 9.0; Windows NT ...  US  1.0
# 3556  Mozilla/5.0 (Windows NT 5.1) AppleWebKit/535.1...  US  0.0
# 3557                             GoogleMaps/RochesterNY  US  0.0
# 3558                                     GoogleProducer  US  0.0
# 3559  Mozilla/4.0 (compatible; MSIE 8.0; Windows NT ...  US  0.0
#
#                        tz  gr       g       h             l              al  \
# 0        America/New_York  MA  A6qOVH  wfLQtf       orofrog  en-US,en;q=0.8
# ...

# %%
# importing pandas as pd
import pandas as pd
  
# Creating the DataFrame
df = pd.DataFrame({"A":[12, 4, 5, None, 1], 
                   "B":[7, 2, 54, 3, None], 
                   "C":[20, 16, 11, 3, 8], 
                   "D":[14, 3, None, 2, 6]}) 
  
# Create the index
index_ = ['Row_1', 'Row_2', 'Row_3', 'Row_4', 'Row_5']
  
# Set the index
df.index = index_

# %%
 for index, column_name in df.columns:
   print(f"{index} : {column_name}")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-3-a59be025deb9> in <module>()
# ----> 1 for index, column_name in df.columns:
#       2   print(f"{index} : {column_name}")
#
# ValueError: not enough values to unpack (expected 2, got 1)

# %%
a_list= pd.Series([lmao.split()[0] for lmao in df['a'].dropna()])
a_list
# Out:
# 0                  Mozilla/5.0
# 1       GoogleMaps/RochesterNY
# 2                  Mozilla/4.0
# 3                  Mozilla/5.0
# 4                  Mozilla/5.0
#                  ...
# 3435               Mozilla/4.0
# 3436               Mozilla/5.0
# 3437    GoogleMaps/RochesterNY
# 3438            GoogleProducer
# 3439               Mozilla/4.0
# Length: 3440, dtype: object

# %%
import numpy as np


df_full = df[df['a'].notnull()]
df_full['ex'] = np.where(df_full.a.str.contains('Windows'), 'Windows', 'Non-Windows')
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """

# %%
df_group= df_full.groupby(['tz', 'ex'])
df_group1=df_group['tz', 'ex'].size().unstack().fillna(0)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.

# %%
df_group1= df_group1.stack()
df_group1.name = "total"
df_group1 = df_group1.reset_index()
df_group1
# Out:
#                     tz           ex  total
# 0                       Non-Windows  245.0
# 1                           Windows  276.0
# 2         Africa/Cairo  Non-Windows    0.0
# 3         Africa/Cairo      Windows    3.0
# 4    Africa/Casablanca  Non-Windows    0.0
# ..                 ...          ...    ...
# 189      Europe/Zurich      Windows    0.0
# 190   Pacific/Auckland  Non-Windows    3.0
# 191   Pacific/Auckland      Windows    8.0
# 192   Pacific/Honolulu  Non-Windows    0.0
# 193   Pacific/Honolulu      Windows   36.0
#
# [194 rows x 3 columns]

# %%
import seaborn as sns

df_group2= df_group1[-10:]

sns.barplot(y='tz', x= 'total', hue= 'ex' , data= df_group2 )

# %%
df_group2['normalized']= df_group2.total/df_group2.total.sum()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
import seaborn as sns
sns.barplot(y=subset.index, x=subset.values)

# %%
def tail (filename, n=10):
  with open(filename, "r") as f:
     lines = f.readlines ()
  for line in lines[len(lines)- n:]:
    print(line)

# %%
tail('nonso.txt', )
# Out:
# i sthis working
#
# i think it is
#
# yes it is
#
# when did it start working
#
# i dont know

# %%
import re

def parse1():
    for line in open("log.txt"):
        print(line.split("[")[1].split("]")[0])

def parse2():
    for line in open("log.txt", "r"):
        print(line.split()[3].strip("[]"))

def parse3():
    for line in open("log.txt", "r"):
        print(" ".join(line.split("[" or "]")[3:5]))

def parse4():
    for line in open("log.txt", "rw"):
        print(" ".join(line.split()[3:5]).strip("[]"))
  
def parse5():
    for line in open("log.txt"):
        print(re.split("\[|\]", line)[1])

# %%
# print(parse1())
print(parse2())
print(parse3())
# print(parse4())
# print(parse5())
# Out:
# 01/Mar/2022:13:05:05
# 01/Mar/2022:13:05:10
# None
#
#
# None

# %%
class BaseLayer:
    def __init__(self, name=""):
        self.name = name

    def __repr__(self):
        return f"{self.name}Layer"

class ActivationLayer(BaseLayer):
    def __init__(self, size):
        super().__init__("Activation")
        self.size = size

class FCLayer(BaseLayer):
    def __init__(self, size):
        super().__init__("FullyConnected")
        self.size = size

# %%
import requests

links =  "https://dhis2nigeria.org.ng/dhis/api/29/analytics.csv?dimension=dx:mz0LIaWBAz9.HBvhntn3sam;mz0LIaWBAz9.k5pHlvkYR3T;mz0LIaWBAz9.jaAWWXYY0mP&dimension=pe:LAST_MONTH&dimension=ou:s5DPBsdoE8b;LEVEL-1;LEVEL-2&displayProperty=NAME&tableLayout=true&columns=dx&rows=pe;ou"

response = requests.get(links,
                                auth=("FMOH_ePHD", "@e4eDHIS2"))

response.content
# Out:
# b'periodid,periodname,periodcode,perioddescription,organisationunitid,organisationunitname,organisationunitcode,organisationunitdescription,Deaths < 5 Diarrhoea - Under 5,Deaths < 5 Malaria - U5,Deaths < 5 Pneumonia\n202206,June 2022,202206,,Nko8QFDmYmq,an Anambra state,,,,,\n202206,June 2022,202206,,FHlOerryBjk,ab Abia State,,,,,\n202206,June 2022,202206,,OgjFloqKoqk,ad Adamawa State,,,,6.0,1.0\n202206,June 2022,202206,,qLiKWoddwFu,ak Akwa-Ibom State,,,,,\n202206,June 2022,202206,,ziJ3yxfgb3m,ba Bauchi State,,,,30.0,2.0\n202206,June 2022,202206,,MXrZyuS9E7A,be Benue State,,,,11.0,\n202206,June 2022,202206,,RLySnRCE1Gy,bo Borno State,,,,2.0,\n202206,June 2022,202206,,ns3vF75Y0bF,by Bayelsa State,,,,4.0,\n202206,June 2022,202206,,caG44DzHu6F,cr Cross River State,,,,65.0,3.0\n202206,June 2022,202206,,m0rZG06GdPe,de Delta State,,,,2.0,1.0\n202206,June 2022,202206,,xWSEoKmrbBW,eb Ebonyi State,,,,5.0,1.0\n202206,June 2022,202206,,aMQcvAoEFh0,ed Edo State,,,,4.0,8.0\n202206,June 2022,20220
# ...

# %%
import csv
import pandas as pd
import requests
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

new_data =response.content.decode('utf-8').splitlines().copy()

data_file = open("pou.csv", 'w', newline='')

      # create the csv writer object
csv_writer = csv.writer(data_file, delimiter='\t')

for lines in new_data:
    # writing data to csv file
        csv_writer.writerow([lines])

        # close file object
data_file.close()

# %%
data_file
# Out:
# <_io.TextIOWrapper name='pou.csv' mode='w' encoding='UTF-8'>

# %%
import csv
import pandas as pd
import requests
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

new_df = pd.read_csv("CV1.csv")
new_df
# Out:
#     Unnamed: 0  periodid periodname  periodcode  perioddescription  \
# 0            0    202206  June 2022      202206                NaN
# 1            1    202206  June 2022      202206                NaN
# 2            2    202206  June 2022      202206                NaN
# 3            3    202206  June 2022      202206                NaN
# 4            4    202206  June 2022      202206                NaN
# 5            5    202206  June 2022      202206                NaN
# 6            6    202206  June 2022      202206                NaN
# 7            7    202206  June 2022      202206                NaN
# 8            8    202206  June 2022      202206                NaN
# 9            9    202206  June 2022      202206                NaN
# 10          10    202206  June 2022      202206                NaN
# 11          11    202206  June 2022      202206                NaN
# 12          12    202206  June 2022      202206                NaN
# ...

# %%
new_df.to_csv("CV1.csv")

# %%
required_columns = ['organisationunitname',
           'Deaths < 5 Diarrhoea - Under 5',
           'Deaths < 5 Malaria - U5',
           'Deaths < 5 Pneumonia']

map_data = new_df[required_columns]
# Fill in null values
map_data.fillna(0, inplace=True)
map_data.drop([26], inplace=True)
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:5182: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   downcast=downcast,
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:4913: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
map_data
# Out:
#             organisationunitname  Deaths < 5 Diarrhoea - Under 5  \
# 0               an Anambra state                             0.0
# 1                  ab Abia State                             0.0
# 2               ad Adamawa State                             0.0
# 3             ak Akwa-Ibom State                             0.0
# 4                ba Bauchi State                             0.0
# 5                 be Benue State                             0.0
# 6                 bo Borno State                             0.0
# 7               by Bayelsa State                             0.0
# 8           cr Cross River State                             0.0
# 9                 de Delta State                             0.0
# 10               eb Ebonyi State                             0.0
# 11                  ed Edo State                             0.0
# 12                ek Ekiti State                             0.0
# ...

# %%
map_data.columns
# Out:
# Index(['organisationunitname', 'Deaths < 5 Diarrhoea - Under 5',
#        'Deaths < 5 Malaria - U5', 'Deaths < 5 Pneumonia'],
#       dtype='object')

# %%
# Out:
# 37

# %%
map_data['Deaths < 5 Diarrhoea - Under 5'].value_counts()
# Out:
# 0.0    37
# Name: Deaths < 5 Diarrhoea - Under 5, dtype: int64

# %%
states = [
            "Abia",
            "Adamawa",
            "Akwa-Ibom",
            "Anambra",
            "Bauchi",
            "Bayelsa",
            "Benue",
            "Borno",
            "Cross River",
            "Delta",
            "Ebonyi",
            "Edo",
            "Ekiti",
            "Ogun",
            "Ondo",
            "Osun",
            "Oyo",
            "Enugu",
            "Federal Capital Territory",
            "Gombe",
            "Imo",
            "Jigawa",
            "Kaduna",
            "Kano",
            "Katsina",
            "Kebbi",
            "Kogi",
            "Kwara",
            "Lagos",
            "Nasarawa",
            "Niger",
            "Plateau",
            "Rivers",
            "Sokoto",
            "Taraba",
            "Yobe",
            "Zamfara"
        ]

        # Create list of states data in correct order
diarrhoea_list = []
malaria_list = []
pneumonia_list = []

# %%
for state in states:
    for index, state_name, diarrhoea, malaria, pneumonia in map_data.itertuples():
        if state in state_name:
            diarrhoea_list.append(
                list(map_data[map_data["organisationunitname"] ==
                              state_name].iloc[0, :].values)[1])
            
            
            malaria_list.append(
                list(map_data[map_data["organisationunitname"] ==
                              state_name].iloc[0, :].values)[2])
            pneumonia_list.append(
                list(map_data[map_data["organisationunitname"] ==
                              state_name].iloc[0, :].values)[3])

# %%
malaria_list
# Out:
# [0.0,
#  6.0,
#  0.0,
#  0.0,
#  30.0,
#  4.0,
#  11.0,
#  2.0,
#  65.0,
#  2.0,
#  5.0,
#  4.0,
#  0.0,
#  1.0,
#  3.0,
#  0.0,
#  2.0,
#  0.0,
#  1.0,
#  16.0,
#  1.0,
#  35.0,
#  19.0,
#  28.0,
#  106.0,
#  12.0,
#  1.0,
#  1.0,
#  1.0,
#  12.0,
#  11.0,
#  6.0,
#  2.0,
#  18.0,
#  9.0,
#  22.0,
#  12.0]

# %%
new_dict_diarrhoe= pd.Series(map_data['Deaths < 5 Diarrhoea - Under 5'].values, 
                             index=map_data.organisationunitname).to_dict()
                             
new_dict_malaria= pd.Series(map_data['Deaths < 5 Malaria - U5'].values, 
                             index=map_data.organisationunitname).to_dict()
new_dict_pneumonia= pd.Series(map_data['Deaths < 5 Pneumonia'].values, 
                             index=map_data.organisationunitname).to_dict()

new_dict_malaria = sorted(new_dict_malaria.items(), key=lambda x: x[0], reverse=False)

# dictttt= [gellato for gellato in new_dict_malaria.values() ]
print(new_dict_malaria)
# Out:
# [('ab Abia State', 0.0), ('ad Adamawa State', 6.0), ('ak Akwa-Ibom State', 0.0), ('an Anambra state', 0.0), ('ba Bauchi State', 30.0), ('be Benue State', 11.0), ('bo Borno State', 2.0), ('by Bayelsa State', 4.0), ('cr Cross River State', 65.0), ('de Delta State', 2.0), ('eb Ebonyi State', 5.0), ('ed Edo State', 4.0), ('ek Ekiti State', 0.0), ('en Enugu State', 0.0), ('fc Federal Capital Territory', 1.0), ('go Gombe State', 16.0), ('im Imo State', 1.0), ('ji Jigawa State', 35.0), ('kd Kaduna State', 19.0), ('ke Kebbi State', 12.0), ('kn Kano State', 28.0), ('ko Kogi State', 1.0), ('kt Katsina State', 106.0), ('kw Kwara State', 1.0), ('la Lagos State', 1.0), ('na Nasarawa State', 12.0), ('ni Niger State', 11.0), ('og Ogun State', 1.0), ('on Ondo State', 3.0), ('os Osun State', 0.0), ('oy Oyo State', 2.0), ('pl Plateau State', 6.0), ('ri Rivers State', 2.0), ('so Sokoto State', 18.0), ('ta Taraba State', 9.0), ('yo Yobe State', 22.0), ('za Zamfara State', 12.0)]

# %%
! pip install geopandas
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 1.0 MB 5.1 MB/s
# ...
#      |████████████████████████████████| 16.7 MB 45.0 MB/s
# ...
#      |████████████████████████████████| 6.3 MB 50.4 MB/s
# ...

# %%
pd.set_option('display.max_rows', None)

# %%
import geopandas as gpd
map_df = gpd.read_file(f"Integrated_DataFrame.geojson")
map_df.columns
# Out:
# Index(['Name', 'description', 'timestamp', 'id', 'country', 'enname',
#        'locname', 'offname', 'boundary', 'adminlevel', 'wikidata', 'wikimedia',
#        'note', 'path', 'rpath', 'iso3166_2', 'Confirmed Cases', 'Active Cases',
#        'No. Discharged', 'Deaths', 'State_Lat', 'State_Lon', 'geometry'],
#       dtype='object')

# %%
import numpy as np
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
import scipy.stats as stats
import datetime
from sklearn.ensemble import IsolationForest
from sklearn.covariance import EllipticEnvelope
sns.set_style("darkgrid")

# %%
df['Values']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-2a538fc5bf6a> in <module>()
# ----> 1 df['Values']
#
# NameError: name 'df' is not defined

# %%
df = pd.read_csv('outlierAnalysis.csv')
df1 = df.sample(frac = 0.6)
sns.histplot(data=df1, x="Values")
plt.show()

# %%
region_data = {
    "North Central": ["Benue", "Kogi", "Kwara", "Nasarawa", "Niger", "Plateau",
                      "Federal Capital Territory",
                      "FCT",
                      "Abuja"],
    "North East": ["Adamawa", "Bauchi", "Borno", "Gombe", "Taraba", "Yobe"],
    "North West": ["Jigawa", "Kaduna", "Kano", "Katsina", "Kebbi", "Sokoto", "Zamfara"],
    "South East": ["Abia", "Anambra", "Ebonyi", "Enugu", "Imo"],
    "South South": ["Akwa Ibom", "Bayelsa", "Cross River", "Rivers", "Delta", "Edo"],
    "South West": ["Ekiti", "Lagos", "Ogun", "Ondo", "Osun", "Oyo"]}

entry = "I am from Anambra State"

# for key, value in region_data.items():
#     for state in value:
#         if state in entry:
#             print(key)

for key, values in region_data.items():
  if any(value in entry for value in values):
    return key

return "Unspecified"
# Out:
# South East

# %%
"""
THIS MODULE CONTAINS THE CODES REQUIRED THE GENERATE THE CHARTS FOR THE NHMIS BULLETIN
"""
import csv
import pandas as pd
import requests
import slack

# Google Sheet interactions
import gspread
from google.oauth2 import service_account
from google.auth.transport.requests import AuthorizedSession
from gspread_dataframe import set_with_dataframe, get_as_dataframe


# Apache Airflow Server details or Google Drive Location



class DataGenerator:
	"""
	This class is responsible for the generation of the data for the NHMIS Bulletin
	"""

	def __init__(self):
		self.links = "https://dhis2nigeria.org.ng/dhis/api/29/analytics.csv?dimension=dx:HVZTC0vlhW9;O82o1WlMisO.REPORTING_RATE_ON_TIME;O82o1WlMisO.REPORTING_RATE;Jc1WjNKrObY;KWJ3cSuyzs4;SCDCoP6l9vz;k2Ncm24FnEA;dCQZ2WnhEwE;HH0iQLlqddM;UVw96W1kcja;YjZiHDKMWCJ;CvX3NUIe50P;rgmSg4j5CRD;HhWjY78dECn;iWQ9dIazJD4;bKSVofVt1vy;BFeSKtHhPKi;m5gTF1jKQjl;GEd2F6skCpT;G7iWnz9RMy9;mz0LIaWBAz9.k5pHlvkYR3T;mz0LIaWBAz9.jaAWWXYY0mP;mz0LIaWBAz9.HBvhntn3sam;wGPpop3rz7i;rXoqTMxWvfR&dimension=pe:LAST_6_MONTHS&dimension=ou:s5DPBsdoE8b;LEVEL-1&displayProperty=NAME&tableLayout=true&columns=dx&rows=pe;ou"
		self.map_links = "https://dhis2nigeria.org.ng/dhis/api/29/analytics.csv?dimension=dx:mz0LIaWBAz9.HBvhntn3sam;mz0LIaWBAz9.k5pHlvkYR3T;mz0LIaWBAz9.jaAWWXYY0mP&dimension=pe:LAST_MONTH&dimension=ou:s5DPBsdoE8b;LEVEL-1;LEVEL-2&displayProperty=NAME&tableLayout=true&columns=dx&rows=pe;ou"
		self.bulletin_link = "https://docs.google.com/spreadsheets/d/1IFXvFLIkJx0PXhhc0pjJ5KdSQ1dVygTEcAtF3e4lRgY/edit#gid=273934337"
		# self.credentials_path = f"{BASE_FOLDER}/extract_data.json"
		# self.scope = ["https://www.googleapis.com/auth/spreadsheets"]
		# self.credentials = service_account.Credentials.from_service_account_file(
		# 	self.credentials_path, scopes=self.scope)
		# self.scoped_credentials = self.credentials.with_scopes(
		# 	self.scope
		# )
		self.worksheet_id = "1IFXvFLIkJx0PXhhc0pjJ5KdSQ1dVygTEcAtF3e4lRgY"
		self.extracted_chart_data = pd.DataFrame()
		self.all_data = pd.DataFrame()

	@staticmethod
	def extract_data(links):
		"""
		  This function is used to extract the report straight from DHIS2
		  Args:
			  links: NHMIS urls containing links to the data

		  Returns:
			  The required data
		  """
		csv_file_path = f"msdat_data.csv"

		def create_csv_file(new_data):
			"""
			Function to write downloaded data into csv for easy  manipulation

			output:
			- A csv file containing data downloaded

			"""
			# create an empty csv file

			data_file = open(csv_file_path, 'w', newline='')

			# create the csv writer object
			csv_writer = csv.writer(data_file, delimiter='\t')

			for lines in new_data:
				# writing data to csv file
				csv_writer.writerow([lines])

			# close file object
			data_file.close()

		response = requests.get(links,
		                        auth=("FMOH_ePHD", "@e4eDHIS2"))
		data = response.content

		# decode from bytes to string and then lists
		new_data = data.decode('utf-8').splitlines().copy()

		create_csv_file(new_data)
		# read new csv file created
		new_df = pd.read_csv(csv_file_path)

		return new_df

	def extract_chart_data(self):
		self.extracted_chart_data = self.extract_data(self.links)
		unwanted = ['periodid', 'periodcode', 'perioddescription', 'organisationunitid', 'organisationunitname',
		            'organisationunitcode',
		            'organisationunitdescription']

		self.extracted_chart_data.drop(unwanted, axis=1, inplace=True)
		self.extracted_chart_data.to_csv(f'extracted_data.csv', index=False)

	# def export_data(self):
	# 	"""
	# 	This is used to export data to Google Sheet

	# 	data_retrieved: DataFrame object
	# 	sheet_name: Name of the sheet that the data is being uploaded to
	# 	"""
	# 	clean_data = pd.read_csv(f'{BASE_FOLDER}/clean_data.csv',
	# 	                         index_col=None)
		
	# 	gc = gspread.Client(auth=self.scoped_credentials)
	# 	gc.session = AuthorizedSession(self.scoped_credentials)
	# 	worksheet_object = gc.open_by_key(self.worksheet_id)

	# 	# Upload data to sheet
	# 	data_sheet = worksheet_object.worksheet("bulletin_data")
	# 	set_with_dataframe(data_sheet, clean_data)

	def transform_data(self):
		"""
		Transforms the extracted data to the format needed for the bulletin.
		The output is also exported to a Google Sheet for reference
		Returns : None
		"""
		extracted_data = pd.read_csv(f'extracted_data.csv',
		                             index_col=None)

		all_dataframes = []
		for col in extracted_data.columns[1:]:
			new_dataframe = pd.DataFrame(columns=['Period',
			                                      'Organisation',
			                                      'Indicator',
			                                      'Value',
			                                      'Source',
			                                      'Indicator_datasource'])

			new_dataframe['Period'] = extracted_data['periodname']
			new_dataframe['Organisation'] = "National"
			new_dataframe['Indicator'] = col
			new_dataframe['Value'] = extracted_data[col]
			new_dataframe['Source'] = 'NHMIS'
			new_dataframe['Indicator_datasource'] = f"{col}->NHMIS"
			all_dataframes.append(new_dataframe)

		self.all_data = pd.concat(all_dataframes)
		


	def extract_opv(self):
		"""
		Groups the Different OPVs i.e OPV0, OPV1 by months and aggregate them by their sum.
		Append the resulting dataframe back the filtered dataframe

		"""
	
		 #Filters out entries that have OpV andentries that dont have OPV
		df_no_opv = self.all_data[~self.all_data['Indicator_datasource'].str.contains("OPV")] 
		df_new_2 = self.all_data[self.all_data['Indicator_datasource'].str.contains("OPV")]

		groupby_df= df_new_2.groupby('Period', as_index = False)['Value'].sum() 
		groupby_df["Organisation"]= "National"   #Adding the other column to match the main df
		groupby_df["Indicator"]= "OPV Birth"
		groupby_df["Source"]= "NHMIS"
		groupby_df["Indicator_datasource"]= "OPV->NHMIS"

		final_df= pd.concat([df_no_opv, groupby_df], axis=0)
		final_df.reset_index(inplace=True, drop=True,)

		final_df.to_csv(f'clean_data.csv', index=False)

	# def send_slack_message(self):
	# 	"""
	# 	This function is used to send slack messages to the channel when the data has been updated.
	# 	"""
	# 	token = "xoxb-9535526721-3000281800049-pWCaWJ4HAywWrADrOLVtjadO"
	# 	slack_message = f"""
	# 	    		        Hello,

	# 	    		        The NHMIS Bulletin Sheet has been updated.

	# 	    		        Please verify data update by using the link below:

	# 	    		        <{self.bulletin_link}|*NHMIS Bulletin Data Update*>

	# 	    		        Regards,

	# 	    		        PyData Team
	# 					"""
	# 	client = slack.WebClient(token=token)

	# 	client.chat_postMessage(channel="#dacissh-discuss",
	# 	                        text=slack_message)

# %%
gen= DataGenerator()

gen.extract_chart_data()

gen.transform_data()
gen.extract_opv()
print(gen.all_data)
# Out:
#            Period Organisation                     Indicator     Value Source  \
# 0   February 2022     National  NHMIS 2019 data completeness      86.4  NHMIS
# 1      March 2022     National  NHMIS 2019 data completeness      86.9  NHMIS
# 2      April 2022     National  NHMIS 2019 data completeness      87.6  NHMIS
# 3        May 2022     National  NHMIS 2019 data completeness      87.9  NHMIS
# 4       June 2022     National  NHMIS 2019 data completeness      87.4  NHMIS
# ..            ...          ...                           ...       ...    ...
# 1      March 2022     National             Patients Admitted  337513.0  NHMIS
# 2      April 2022     National             Patients Admitted  344443.0  NHMIS
# 3        May 2022     National             Patients Admitted  351498.0  NHMIS
# 4       June 2022     National             Patients Admitted  386479.0  NHMIS
# 5       July 2022     National             Patients Admitted  314722.0  NHMIS
#
# ...

# %%
# !pip install slack
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#   Created wheel for slack: filename=slack-0.0.2-py3-none-any.whl size=2527 sha256=e76fee9765e51a552053a0f0ca81029d2f2a255a0e01430e42b0fe9331f76d2a
#   Stored in directory: /root/.cache/pip/wheels/6f/58/77/7d1df1bc7885ffdf2cb2990f4d5552b2d57e3fb4d3507acdfd
# Successfully built slack
# ...

# %%
import requests
response= requests.get('https://msdat-api.fmohconnect.gov.ng/api/data/?datasource=8&indicator=18&size=1000&location=11&value_type=3')
a = response.json()
a
# Out:
# {'count': 17,
#  'next': None,
#  'previous': None,
#  'results': [{'value': '37.16',
#    'id': 1432,
#    'indicator': 18,
#    'period': '2000',
#    'location': 11,
#    'datasource': 8,
#    'value_type': 3,
#    'created_at': '2022-06-16T15:14:15.225948Z',
#    'updated_at': '2022-06-16T15:14:15.225955Z'},
#   {'value': '41.62',
#    'id': 1433,
#    'indicator': 18,
#    'period': '2001',
#    'location': 11,
#    'datasource': 8,
#    'value_type': 3,
#    'created_at': '2022-06-16T15:14:15.229569Z',
#    'updated_at': '2022-06-16T15:14:15.229577Z'},
#   {'value': '47.01',
#    'id': 1434,
#    'indicator': 18,
#    'period': '2002',
#    'location': 11,
#    'datasource': 8,
#    'value_type': 3,
#    'created_at': '2022-06-16T15:14:15.233189Z',
#    'updated_at': '2022-06-16T15:14:15.233197Z'},
#   {'value': '52.24',
#    'id': 1435,
#    'indicator': 18,
#    'period': '2003',
#    'location': 11,
#    'datasource': 8,
#    'value_type': 3,
# ...

# %%
import pandas as pd
df = pd.DataFrame.from_dict(a["results"])
df
# Out:
#     value    id  indicator period  location  datasource  value_type  \
# 0   37.16  1432         18   2000        11           8           3
# 1   41.62  1433         18   2001        11           8           3
# 2   47.01  1434         18   2002        11           8           3
# 3   52.24  1435         18   2003        11           8           3
# 4   60.54  1436         18   2004        11           8           3
# 5   68.02  1437         18   2005        11           8           3
# 6   74.51  1438         18   2006        11           8           3
# 7   76.66  1439         18   2007        11           8           3
# 8   80.86  1441         18   2009        11           8           3
# 9   79.95  1442         18   2010        11           8           3
# 10  78.19  1443         18   2011        11           8           3
# 11  74.24  1444         18   2012        11           8           3
# 12  70.16  1445         18   2013        11           8           3
# ...

# %%
df= df[['period', 'value']]
df['period']= pd.to_datetime(df["period"], format="%Y")

# %%
df.sort_values(by='period', inplace= True)
df
# Out:
#        period  value
# 0  2000-01-01  37.16
# 1  2001-01-01  41.62
# 2  2002-01-01  47.01
# 3  2003-01-01  52.24
# 4  2004-01-01  60.54
# 5  2005-01-01  68.02
# 6  2006-01-01  74.51
# 7  2007-01-01  76.66
# 16 2008-01-01  79.72
# 8  2009-01-01  80.86
# 9  2010-01-01  79.95
# 10 2011-01-01  78.19
# 11 2012-01-01  74.24
# 12 2013-01-01  70.16
# 13 2014-01-01  65.34
# 14 2015-01-01  69.32
# 15 2016-01-01  62.77

# %%
import matplotlib.pyplot as plt
df.set_index("period")
# Out:
#             value
# period
# 2000-01-01  37.16
# 2001-01-01  41.62
# 2002-01-01  47.01
# 2003-01-01  52.24
# 2004-01-01  60.54
# 2005-01-01  68.02
# 2006-01-01  74.51
# 2007-01-01  76.66
# 2008-01-01  79.72
# 2009-01-01  80.86
# 2010-01-01  79.95
# 2011-01-01  78.19
# 2012-01-01  74.24
# 2013-01-01  70.16
# 2014-01-01  65.34
# 2015-01-01  69.32
# 2016-01-01  62.77

# %%
df_new = df.astype({ "value": float})
plt.plot(df_new.period, df_new.value)

# %%
from pmdarima import auto_arima

model=auto_arima(df_new["value"],start_p=0,d=1,start_q=0,
          max_p=5,max_d=5,max_q=5, start_P=0,
          D=1, start_Q=0, max_P=5,max_D=5,
          max_Q=5, m=12, seasonal=True,
          error_action='warn',trace=True,
          supress_warnings=True,stepwise=True,
          random_state=20,n_fits=50)
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(0,1,0)(0,1,0)[12]             : AIC=31.765, Time=0.07 sec
#  ARIMA(1,1,0)(1,1,0)[12]             : AIC=inf, Time=0.67 sec
#  ARIMA(0,1,1)(0,1,1)[12]             : AIC=35.441, Time=0.26 sec
#  ARIMA(0,1,0)(1,1,0)[12]             : AIC=33.765, Time=0.12 sec
#  ARIMA(0,1,0)(0,1,1)[12]             : AIC=33.765, Time=0.14 sec
#  ARIMA(0,1,0)(1,1,1)[12]             : AIC=35.765, Time=0.17 sec
#  ARIMA(1,1,0)(0,1,0)[12]             : AIC=32.993, Time=0.09 sec
#  ARIMA(0,1,1)(0,1,0)[12]             : AIC=33.441, Time=0.20 sec
#  ARIMA(1,1,1)(0,1,0)[12]             : AIC=33.453, Time=0.36 sec
#  ARIMA(0,1,0)(0,1,0)[12] intercept   : AIC=28.048, Time=0.04 sec
#  ARIMA(0,1,0)(1,1,0)[12] intercept   : AIC=30.048, Time=0.05 sec
#  ARIMA(0,1,0)(0,1,1)[12] intercept   : AIC=30.048, Time=0.06 sec
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/statespace/sarimax.py:1899: RuntimeWarning: divide by zero encountered in reciprocal
# ...

# %%
df_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 17 entries, 0 to 15
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   period  17 non-null     datetime64[ns]
#  1   value   17 non-null     float64
# dtypes: datetime64[ns](1), float64(1)
# memory usage: 408.0 bytes

# %%
prediction, confint = model.predict(n_periods=5, return_conf_int=True)

prediction
# Out:
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/base/tsa_model.py:843: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   data=self.data,
# 17    68.105078
# 18    62.098018
# 19    60.185914
# 20    52.310981
# 21    48.116050
# dtype: float64

# %%
confint
# Out:
# array([[62.45789847, 73.75225811],
#        [56.35481193, 67.8412249 ],
#        [52.70415596, 67.66767126],
#        [44.62951499, 59.99244624],
#        [39.34725828, 56.88484145]])

# %%
import numpy as np

prediction_series = pd.DataFrame({"Value":prediction, "period":[max(df["period"])+np.timedelta64(i,'Y') for i in range(1, 6) ]})

# %%
prediction_series["period"]= prediction_series['period'].dt.strftime('%Y/%m/%d')
prediction_series['period']= pd.to_datetime(prediction_series["period"])
prediction_series= prediction_series.set_index("period")
prediction_series
# Out:
#                 Value
# period
# 2016-12-31  68.105078
# 2017-12-31  62.098018
# 2018-12-31  60.185914
# 2019-12-31  52.310981
# 2020-12-31  48.116050

# %%
prediction_series.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 5 entries, 2016-12-31 to 2020-12-31
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Value   5 non-null      float64
# dtypes: float64(1)
# memory usage: 80.0 bytes

# %%
plt.plot(df_new.period, df_new.value)
plt.plot(prediction_series.index, prediction_series["Value"])
plt.show()
